# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# file_path=r"D:\important\datascience\Skill craft Internship\skill.csv"
# df=pd.read_csv(file_path)

# %%
df=pd.read_csv("Age and Pop.csv")
df
# Out:
#     Person_ID  Age  Gender           State Marital_Status
# 0           1   25    Male   Uttar Pradesh         Single
# 1           2   30  Female     Maharashtra        Married
# 2           3   45    Male      Tamil Nadu        Married
# 3           4   50  Female       Karnataka        Married
# 4           5   35  Female         Gujarat         Single
# ..        ...  ...     ...             ...            ...
# 95         96   25    Male  Andhra Pradesh        Married
# 96         97   35    Male     Maharashtra        Married
# 97         98   41    Male           Delhi        Married
# 98         99   46  Female           Assam         Single
# 99        100   56  Female          Kerala         Single
#
# [100 rows x 5 columns]

# %%
df.head()
# Out:
#    Person_ID  Age  Gender          State Marital_Status
# 0          1   25    Male  Uttar Pradesh         Single
# 1          2   30  Female    Maharashtra        Married
# 2          3   45    Male     Tamil Nadu        Married
# 3          4   50  Female      Karnataka        Married
# 4          5   35  Female        Gujarat         Single

# %%
df.describe()
# Out:
#         Person_ID         Age
# count  100.000000  100.000000
# mean    50.500000   42.060000
# std     29.011492   16.252316
# min      1.000000   15.000000
# 25%     25.750000   28.750000
# 50%     50.500000   41.000000
# 75%     75.250000   54.250000
# max    100.000000   75.000000

# %%
# Create the histogram
import seaborn as sns
sns.histplot(df['Age'], bins=10, kde=True, edgecolor='black', color='blue')
plt.title("Population distribution by Age")
# Out:
# Text(0.5, 1.0, 'Population distribution by Age')

# %% [markdown]
# ##### Insight : Age group from 30 to 40 and 45 to 50 is maximum in this population dataset.
